# %% [markdown]
# # 05-01 데이터 시각화 기초

# %% [markdown]
# ## 데이터 시각화 개요

# %% [markdown]
# - 그래프의 여러 속성

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='Malgun Gothic')
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rc('axes', unicode_minus=False)
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# - plt.title()과 label()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [10, 20, 30, 40])
plt.title('plotting')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [10, 20, 30, 40], label='ascending')
plt.plot([1, 2, 3, 4], [40, 30, 20, 10], label='descending')

plt.title('legend')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
plt.axis((0, 6, 0, 20))
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [10, 20, 30, 40], color='skyblue', label='skyblue')
plt.plot([1, 2, 3, 4], [40, 30, 20, 10], 'pink', label='pink', )

plt.title('Color')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [10, 20, 30, 40], color='r', linestyle='--', label='dashed')
plt.plot([1, 2, 3, 4], [40, 30, 20, 10], 'b', ls=':', label='dotted')

plt.title('Linestyle')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [10, 20, 30, 40], color='y', linestyle='--', label='dashed')
plt.plot([1, 2, 3, 4], [40, 30, 20, 10], 'b', ls=':', label='dotted')
plt.plot([1, 2, 3, 4], [5, 10, 35, 45], color='b', linestyle='-.', label='dashed dot')
plt.plot([1, 2, 3, 4], [10, 30, 45, 50], 'm', ls='-', label='solid line')

plt.title('Linestyle')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.legend()
plt.show()

# %% [markdown]
# - 마커

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [10, 20, 30, 40], color='r', linestyle='--', marker='d', label='thin diamond')
plt.plot([1, 2, 3, 4], [40, 30, 20, 10], 'b', ls=':', marker='^', label='triangle up')

plt.title('Marker')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [10, 20, 30, 40], color='r', linestyle='--', marker='d', label='thin diamond')
plt.plot([1, 2, 3, 4], [10, 15, 35, 50], color='g', linestyle='-.', marker='D', label='diamond')
plt.plot([1, 2, 3, 4], [40, 30, 20, 10], 'b', ls=':', marker='^', label='triangle up')

plt.title('Marker')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [10, 20, 30, 40], 'r.', label='circle')
plt.plot([1, 2, 3, 4], [40, 30, 20, 10], 'g^', label='triangle up')

plt.title('short string style')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [40, 30, 20, 10], 'g^', label='triangle up',)

plt.title('string style')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [10, 20, 30, 35], '-ro', label='circle')
plt.plot([1, 3, 4, 5], [10, 30, 20, 10], '-.g^', label='triangle up')
plt.plot([4, 3, 2, 1], [10, 30, 20, 10], ':m>', label='right triagle up')
plt.plot([5, 4, 3, 1], [10, 20, 30, 40], '1c--', label='triangle up')

plt.title('short string style')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([10, 20, 30, 40], [1, 4, 9, 16], c='b',
         lw=5, ls='--', marker='o', ms=15, mec='g', mew=5, mfc='r')

plt.title('marker style')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([10, 20, 30, 40], [1, 4, 9, 16], '-.bo', lw=3, ms=8, mec='skyblue', mew=2, mfc='pink')

plt.title('marker style')
plt.show()

# %% [markdown]
# - 경고 메시지 제어

# %%
import warnings

# 경고 메시지를 무시하고 숨기거나
warnings.filterwarnings(action='ignore') 

# 숨기기했던 경고 메시지를 다시 보이게
warnings.filterwarnings(action='default')

# %% [markdown]
# - 한글 포트

# %%
import matplotlib as mpl
from matplotlib import font_manager

font_list = sorted([f.name for f in font_manager.fontManager.ttflist])
font_list
# Out:
# ['Agency FB',
#  'Agency FB',
#  'Algerian',
#  'Ami R',
#  'Arial',
#  'Arial',
#  'Arial',
#  'Arial',
#  'Arial',
#  'Arial',
#  'Arial',
#  'Arial',
#  'Arial',
#  'Arial Rounded MT Bold',
#  'Bahnschrift',
#  'Baskerville Old Face',
#  'Batang',
#  'Bauhaus 93',
#  'Bell MT',
#  'Bell MT',
#  'Bell MT',
#  'Berlin Sans FB',
#  'Berlin Sans FB',
#  'Berlin Sans FB Demi',
#  'Bernard MT Condensed',
#  'Blackadder ITC',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Book Antiqua',
#  'Book Antiqua',
#  'Book Antiqua',
#  'Book Antiqua',
#  'Bookman Old Style',
#  'Bookman Old Style',
#  'Bookman Old Style',
#  'Bookman Old Style',
#  'Bookshelf Symbol 7',
#  'Bradley Hand ITC',
#  'Britannic Bold',
#  'Broadway',
#  'Brush Script MT',
#  'Calibri',
#  'Calibri',
#  'Calibri',
#  'Calibri',
#  'Calibri',
#  'Calibri',
#  'Californian FB',
# ...

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='Malgun Gothic')

plt.plot([-2, -1, 0, 1, 2, 3], [20, 30, 15, 40, 45, 35], label= '선 1')
plt.plot([-2, -1, 0, 1, 2, 3], [-25, 10, 35, 20, 15, 25], label= '선 2')

plt.title('선 그래프 예제')
plt.xlabel('X 축')
plt.ylabel('Y 축')
plt.legend() # 범례 표시
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False

x = np.arange(-10, 10, 0.1)
plt.plot(x, x**2)

plt.xticks(np.arange(-10, 11, 2)) # X 눈금
plt.yticks(np.arange(0, 101, 10)) # Y 눈금
plt.grid(True)

plt.title('선 그래프 예제')
plt.show()

# %% [markdown]
# - 도수분포표

# %%
import matplotlib.pyplot as plt
import numpy as np

data = [1, 1, 2, 3, 4, 5, 6, 6, 8, 10]
arrays, bins, patches = plt.hist(data, bins=np.arange(0.5, 11.5), rwidth=.9)
plt.xticks(np.arange(11)) # x축 눈금 모두 표시
plt.show()

# %%
arrays
# Out:
# array([2., 1., 1., 1., 1., 2., 0., 1., 0., 1.])

# %%
bins
# Out:
# array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5])

# %% [markdown]
# - 주사위 시뮬레이션

# %%
import random

print(random.randint(1, 6))
# Out:
# 5

# %%
import random as rd

dice = []
for i in range(5):
    dice.append(rd.randint(1, 6))
print(dice)

dice = [rd.randint(1, 6) for i in range(5)]
print(dice)
# Out:
# [2, 5, 5, 2, 2]
# [6, 3, 4, 5, 6]

# %%
help(rd.choices)
# Out:
# Help on method choices in module random:
#
# choices(population, weights=None, *, cum_weights=None, k=1) method of random.Random instance
#     Return a k sized list of population elements chosen with replacement.
#
#     If the relative weights or cumulative weights are not specified,
#     the selections are made with equal probability.

# %%
rd.choices(range(1, 7), k=20)
# Out:
# [2, 2, 6, 2, 4, 1, 6, 2, 6, 2, 6, 1, 4, 3, 2, 4, 4, 3, 5, 6]

# %%
import random as rd
import numpy as np
import matplotlib.pyplot as plt

dice = [rd.randint(1, 6) for i in range(5)]
plt.hist(dice, bins=np.arange(0.5, 7), rwidth=.9)
plt.xticks(range(1, 7))
plt.show()

# %%
import random as rd
import numpy as np
import matplotlib.pyplot as plt

dice = [rd.randint(1, 6) for i in range(1000000)]
plt.hist(dice, bins=np.arange(0.5, 7))
plt.xticks(range(1, 7))
plt.show()

# %% [markdown]
# - box plot

# %%
import matplotlib.pyplot as plt
import random

result = [random.randint(1, 1000) for i in range(13)]
print(sorted(result))
plt.boxplot(result)
plt.show()
# Out:
# [17, 34, 124, 139, 237, 293, 354, 386, 517, 590, 648, 692, 995]

# %%
import matplotlib.pyplot as plt
import random

# result = [random.randint(1, 1000) for i in range(13)] 
result = random.choices(range(1, 1000), k=13)
print(sorted(result))

plt.boxplot(result)
plt.show()
# Out:
# [87, 102, 171, 173, 206, 293, 448, 469, 649, 707, 821, 855, 970]

# %%
import matplotlib.pyplot as plt
import random

result1 = []
result2 = []
for i in range(13):
    result1.append(random.randint(1, 500))
    result2.append(random.randint(501, 1000))
    

plt.boxplot(result1)
plt.boxplot(result2)
plt.show()

# %%
import matplotlib.pyplot as plt
import random

result1 = random.choices(range(1, 500), k=13)
result2 = random.choices(range(501, 1000), k=13)

plt.boxplot(result1)
plt.boxplot(result2)
plt.show()

# %%
import matplotlib.pyplot as plt
import random

result1 = random.choices(range(1, 500), k=13)
result2 = random.choices(range(501, 1000), k=13)

plt.boxplot([result1, result2])
plt.show()

# %% [markdown]
# - figure()

# %%
import random
import numpy as np
import matplotlib.pyplot as plt

w, h = 10, 2
f1 = plt.figure(figsize=(w, h))
plt.plot([random.randint(1, 100) for i in range(100)])

plt.title(f"figure size : ({w}, {h})")
plt.show()

# %% [markdown]
# plt.subplot()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 3))

# 서브플롯 생성
plt.subplot(1, 2, 1)  # 2행 1열의 서브플롯 중 첫 번째
plt.plot([1, 2, 3, 4])
plt.title("Subplot 1")

plt.subplot(1, 2, 2)  # 2행 1열의 서브플롯 중 두 번째
plt.plot([4, 3, 2, 1])
plt.title("Subplot 2")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

x1 = np.linspace(0.0, 5.0) # num=50 기본 값
x2 = np.linspace(0.0, 2.0) # num=50 기본 값
y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

ax1 = plt.subplot(2, 1, 1)
plt.plot(x1, y1, 'yo-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')

ax2 = plt.subplot(2, 1, 2)
plt.plot(x2, y2, 'r.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')

plt.tight_layout()
plt.show()

# %% [markdown]
# - plt.subplots()

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 3, sharex=True, sharey=True)
plt.show()

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 2)
np.random.seed(0)
axes[0, 0].plot(np.random.rand(5)) # [0, 1) 난수 5개
axes[0, 0].set_title("axes 1")
axes[0, 1].plot(np.random.rand(5))
axes[0, 1].set_title("axes 2")
axes[1, 0].plot(np.random.rand(5))
axes[1, 0].set_title("axes 3")
axes[1, 1].plot(np.random.rand(5))
axes[1, 1].set_title("axes 4")

plt.tight_layout()
plt.suptitle('Figure Title')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 2, sharex=True, sharey=True, figsize=(8, 6))

for i in range(2):
    for j in range(2):
        axes[i, j].hist(np.random.randn(1000), bins=50, color='y', alpha=0.5)

print(plt.rcParams['figure.subplot.wspace'])
print(plt.rcParams['figure.subplot.hspace'])

# 적정한 공간 비우기, 코드없는 것과 동일(기본 값): wspace=.2, hspace=.2 
plt.subplots_adjust(wspace=0, hspace=.05)
plt.show()
# Out:
# 0.2
# 0.2

# %% [markdown]
# - fig.add_subplot()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(7, 5))
data = np.random.randn(50) # 표준 정규분포의 난수 50개

ax2 = fig.add_subplot(2, 2, 2)
plt.plot(data, 'g--')
ax3 = fig.add_subplot(2, 2, 3)
plt.plot(data.cumsum(), 'r.-')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(7, 5))
data = np.random.randn(50) # 표준 정규분포의 난수 50개

ax2 = fig.add_subplot(2, 2, 2)
plt.plot(data, 'g--')
ax3 = fig.add_subplot(2, 2, 3)
plt.plot(data.cumsum(), 'r.-')
plt.show()
