# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.random.randn(10)
data
# Out:
# array([-0.33872051,  0.61866354, -0.04083211, -0.10743045,  0.10829517,
#         0.06108199, -0.7043054 ,  0.30736714, -0.54674154, -0.06209881])

# %%
plt.hist(data,bins=5)
# Out:
# (array([2., 1., 4., 2., 1.]),
#  array([-0.7043054 , -0.43971161, -0.17511782,  0.08947596,  0.35406975,
#          0.61866354]),
#  <BarContainer object of 5 artists>)

# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.random.randn(1000000000)
data

plt.hist(data,bins=10000)
# Out:
# (array([1., 0., 0., ..., 0., 0., 1.]),
#  array([-6.33164799, -6.33041078, -6.32917357, ...,  6.03796053,
#          6.03919774,  6.04043495]),
#  <BarContainer object of 10000 artists>)
